# %%
#很多個文件要匯入組成RAG


# 第1個儲存格：建立多檔案向量資料庫（含元數據）

import os
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# 定義包含文字檔案的目錄和持久化目錄
current_dir = os.path.dirname(os.path.abspath("__file__"))
books_dir = os.path.join(current_dir, "books")
db_dir = os.path.join(current_dir, "db")
persistent_directory = os.path.join(db_dir, "chroma_db_with_metadata_chinese_nb")

print(f"書籍目錄: {books_dir}")
print(f"持久化目錄: {persistent_directory}")

# 檢查 Chroma 向量存儲是否已存在
if not os.path.exists(persistent_directory):
    print("持久化目錄不存在。正在初始化向量存儲...")

    # 確保書籍目錄存在
    if not os.path.exists(books_dir):
        raise FileNotFoundError(
            f"目錄 {books_dir} 不存在。請檢查路徑。"
        )

    # 列出目錄中所有文字檔案
    book_files = [f for f in os.listdir(books_dir) if f.endswith(".txt")]

    # 從每個檔案讀取文字內容並儲存元數據
    documents = []
    for book_file in book_files:
        file_path = os.path.join(books_dir, book_file)
        loader = TextLoader(file_path, encoding='utf-8')
        book_docs = loader.load()
        for doc in book_docs:
            # 為每個文件添加元數據以指示其來源
            doc.metadata = {"source": book_file}
            documents.append(doc)

    # 將文件分割成塊
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
    docs = text_splitter.split_documents(documents)

    # 顯示分割文件的資訊
    print("\n--- 文件塊資訊 ---")
    print(f"文件塊數量: {len(docs)}")

    # 建立嵌入模型
    print("\n--- 正在建立嵌入 ---")
    embeddings = HuggingFaceEmbeddings(
        model_name="jinaai/jina-embeddings-v2-base-zh"
    )
    print("\n--- 完成建立嵌入 ---")

    # 建立並持久化向量存儲
    print("\n--- 正在建立並持久化向量存儲 ---")
    db = Chroma.from_documents(
        docs, embeddings, persist_directory=persistent_directory)
    print("\n--- 完成建立並持久化向量存儲 ---")

else:
    print("向量存儲已存在。無需初始化。")
# Out:
# 書籍目錄: c:\Users\user\Desktop\GITHUB\2025_08.langchain.chilee\lesson7\books
# 持久化目錄: c:\Users\user\Desktop\GITHUB\2025_08.langchain.chilee\lesson7\db\chroma_db_with_metadata_chinese_nb
# 持久化目錄不存在。正在初始化向量存儲...
#
# --- 文件塊資訊 ---
# 文件塊數量: 77
#
# --- 正在建立嵌入 ---
# C:\Users\user\AppData\Local\Temp\ipykernel_22060\2217933162.py:52: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\user\Desktop\GITHUB\2025_08.langchain.chilee\.venv\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub\models--jinaai--jina-embeddings-v2-base-zh. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/322M [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at jinaai/jina-embeddings-v2-base-zh and are newly initialized: ['embeddings.position_embeddings.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.3.intermediate.dense.weight', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.3.output.dense.bias', 'encoder.layer.3.output.dense.weight', 'encoder.layer.4.intermediate.dense.bias', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.4.output.LayerNorm.bias', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.4.output.dense.bias', 'encoder.layer.4.output.dense.weight', 'encoder.layer.5.intermediate.dense.bias', 'encoder.layer.5.intermediate.dense.weight', 'encoder.layer.5.output.LayerNorm.bias', 'encoder.layer.5.output.LayerNorm.weight', 'encoder.layer.5.output.dense.bias', 'encoder.layer.5.output.dense.weight', 'encoder.layer.6.intermediate.dense.bias', 'encoder.layer.6.intermediate.dense.weight', 'encoder.layer.6.output.LayerNorm.bias', 'encoder.layer.6.output.LayerNorm.weight', 'encoder.layer.6.output.dense.bias', 'encoder.layer.6.output.dense.weight', 'encoder.layer.7.intermediate.dense.bias', 'encoder.layer.7.intermediate.dense.weight', 'encoder.layer.7.output.LayerNorm.bias', 'encoder.layer.7.output.LayerNorm.weight', 'encoder.layer.7.output.dense.bias', 'encoder.layer.7.output.dense.weight', 'encoder.layer.8.intermediate.dense.bias', 'encoder.layer.8.intermediate.dense.weight', 'encoder.layer.8.output.LayerNorm.bias', 'encoder.layer.8.output.LayerNorm.weight', 'encoder.layer.8.output.dense.bias', 'encoder.layer.8.output.dense.weight', 'encoder.layer.9.intermediate.dense.bias', 'encoder.layer.9.intermediate.dense.weight', 'encoder.layer.9.output.LayerNorm.bias', 'encoder.layer.9.output.LayerNorm.weight', 'encoder.layer.9.output.dense.bias', 'encoder.layer.9.output.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# --- 完成建立嵌入 ---
#
# --- 正在建立並持久化向量存儲 ---
# BertSdpaSelfAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support non-absolute `position_embedding_type` or `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# --- 完成建立並持久化向量存儲 ---

# %%
# 第2個儲存格：使用元數據過濾查詢

import os
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# 定義持久化目錄
current_dir = os.path.dirname(os.path.abspath("__file__"))
db_dir = os.path.join(current_dir, "db")
persistent_directory = os.path.join(db_dir, "chroma_db_with_metadata_chinese_nb")

# 定義嵌入模型
embeddings = HuggingFaceEmbeddings(model_name="jinaai/jina-embeddings-v2-base-zh")

# 使用嵌入函數載入現有的向量存儲
db = Chroma(persist_directory=persistent_directory,
            embedding_function=embeddings)

# 定義使用者的問題
query = "路由器的WiFi密碼如何更改？"

# 根據查詢檢索相關文件
# search_type="similarity_score_threshold": 使用相似度分數閾值過濾
# k=3: 返回最多 3 個相關文件
# score_threshold=0.1: 較低的閾值，可以返回更多相關文件
retriever = db.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={"k": 3, "score_threshold": 0.1},
)
relevant_docs = retriever.invoke(query)

# 顯示相關結果及元數據
print("\n--- 相關文件 ---")
for i, doc in enumerate(relevant_docs, 1):
    print(f"文件 {i}:\n{doc.page_content}\n")
    print(f"來源: {doc.metadata['source']}\n")

# 進階查詢：只從特定來源檢索
print("\n--- 只從《路由器設定手冊》檢索 ---")
# 使用 filter 參數指定元數據條件
specific_docs = db.similarity_search(
    query,
    k=3,
    filter={"source": "路由器設定手冊.txt"}
)

for i, doc in enumerate(specific_docs, 1):
    print(f"文件 {i}:\n{doc.page_content}\n")
    print(f"來源: {doc.metadata['source']}\n")
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at jinaai/jina-embeddings-v2-base-zh and are newly initialized: ['embeddings.position_embeddings.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.3.intermediate.dense.weight', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.3.output.dense.bias', 'encoder.layer.3.output.dense.weight', 'encoder.layer.4.intermediate.dense.bias', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.4.output.LayerNorm.bias', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.4.output.dense.bias', 'encoder.layer.4.output.dense.weight', 'encoder.layer.5.intermediate.dense.bias', 'encoder.layer.5.intermediate.dense.weight', 'encoder.layer.5.output.LayerNorm.bias', 'encoder.layer.5.output.LayerNorm.weight', 'encoder.layer.5.output.dense.bias', 'encoder.layer.5.output.dense.weight', 'encoder.layer.6.intermediate.dense.bias', 'encoder.layer.6.intermediate.dense.weight', 'encoder.layer.6.output.LayerNorm.bias', 'encoder.layer.6.output.LayerNorm.weight', 'encoder.layer.6.output.dense.bias', 'encoder.layer.6.output.dense.weight', 'encoder.layer.7.intermediate.dense.bias', 'encoder.layer.7.intermediate.dense.weight', 'encoder.layer.7.output.LayerNorm.bias', 'encoder.layer.7.output.LayerNorm.weight', 'encoder.layer.7.output.dense.bias', 'encoder.layer.7.output.dense.weight', 'encoder.layer.8.intermediate.dense.bias', 'encoder.layer.8.intermediate.dense.weight', 'encoder.layer.8.output.LayerNorm.bias', 'encoder.layer.8.output.LayerNorm.weight', 'encoder.layer.8.output.dense.bias', 'encoder.layer.8.output.dense.weight', 'encoder.layer.9.intermediate.dense.bias', 'encoder.layer.9.intermediate.dense.weight', 'encoder.layer.9.output.LayerNorm.bias', 'encoder.layer.9.output.LayerNorm.weight', 'encoder.layer.9.output.dense.bias', 'encoder.layer.9.output.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Users\user\Desktop\GITHUB\2025_08.langchain.chilee\.venv\lib\site-packages\langchain_core\vectorstores\base.py:1070: UserWarning: Relevance scores must be between 0 and 1, got [(Document(metadata={'source': '路由器設定手冊.txt'}, page_content='2.3 使用手機 App設定\n----------------------------------------\n步驟 1：下載 App\n- iOS：至 App Store搜尋「TR Router」\n- Android：至 Play商店搜尋「TR Router」\n- 或掃描說明書上的 QR Code\n\n步驟 2：連接路由器 WiFi\n- 開啟手機 WiFi設定\n- 連接預設 WiFi：TR-5000_XXXX\n- 輸入預設密碼（路由器底部標籤）\n\n步驟 3：開啟 App設定\n1. 啟動 TR Router App\n2. App會自動偵測路由器\n3. 點選「開始設定」\n4. 依畫面指示完成設定\n\n步驟 4：設定內容\n與電腦版相同：\n- 建立管理員密碼\n- 設定網際網路連線\n- 完成後可立即使用\n\n優點：\n- 操作介面更友善\n- 支援遠端管理\n- 即時通知功能\n- 輕鬆管理連線裝置\n\n========================================\n第三章：WiFi 無線網路設定\n========================================\n\n3.1 WiFi 基本設定\n----------------------------------------\n進入 WiFi設定：\n1. 登入管理介面（192.168.1.1）\n2. 點選「無線網路」→「基本設定」\n\n2.4GHz 頻段設定：\n網路名稱（SSID）：\n- 建議使用易記且安全的名稱\n- 避免使用個人資訊（如地址、電話）\n- 支援中文但部分裝置可能無法顯示\n- 範例：Home_2.4G、MyHome_24\n\n安全性設定：\n- 加密方式：選擇「WPA3-Personal」（最安全）\n- 若有舊裝置不支援，選「WPA2/WPA3 混合模式」\n- 密碼長度：8-63字元\n- 建議密碼格式：英文大小寫+數字+符號\n\n頻道設定：\n- 建議選擇「自動」\n- 手動選擇：1、6、11（較少干擾）\n- 頻道寬度：20/40MHz 自動\n\n5GHz 頻段設定：\n網路名稱（SSID）：\n- 建議與 2.4G區分（如加上_5G）\n- 範例：Home_5G、MyHome_5G\n\n頻道設定：\n- 建議選擇「自動」\n- 手動選擇：36、40、44、48（DFS頻段需注意）\n- 頻道寬度：20/40/80MHz 自動'), -0.005861513695532894), (Document(metadata={'source': '信用卡權益說明.txt'}, page_content='額度核定標準：\n- 月收入 3萬：額度約 5-10萬\n- 月收入 5萬：額度約 15-25萬\n- 月收入 10萬：額度約 30-50萬\n- 月收入 15萬以上：額度 50萬以上\n\n1.3 申請方式\n----------------------------------------\n線上申請：\n1. 進入官網申辦頁面\n2. 填寫基本資料\n3. 上傳財力證明\n4. 選擇卡片類型\n5. 等待審核（3-5個工作天）\n6. 核卡後 7個工作天收到卡片\n\n臨櫃申辦：\n1. 攜帶證件至分行\n2. 填寫申請書\n3. 提供財力證明\n4. 專員協助送件\n5. 審核通過後寄卡\n\n電話申辦：\n1. 撥打客服專線\n2. 提供基本資料\n3. 專員錄音確認\n4. 後續補件\n5. 完成申辦\n\n審核流程：\n- 資料送件：1個工作天\n- 審核作業：2-3個工作天\n- 製卡寄發：3-5個工作天\n- 總計：約 1-2週\n\n1.4 卡片啟用與設定\n----------------------------------------\n收到卡片後：\n\n步驟 1：檢查卡片\n□ 確認卡號正確\n□ 檢查姓名拼音\n□ 確認有效期限\n□ 檢查背面簽名欄\n\n步驟 2：簽名\n- 使用原子筆在背面簽名欄簽名\n- 簽名須與證件相符\n- 勿使用鉛筆或立可白\n\n步驟 3：啟用卡片\n方式 A：電話啟用\n1. 撥打 02-8888-9999\n2. 輸入身分證字號\n3. 輸入卡號\n4. 輸入有效月年（MMYY）\n5. 設定電話密碼（6碼）\n\n方式 B：線上啟用\n1. 登入網路銀行\n2. 點選「信用卡啟用」\n3. 輸入卡號與驗證碼\n4. 設定網路交易密碼\n\n方式 C：App啟用\n1. 下載「TW Bank」App\n2. 登入帳號\n3. 選擇「啟用信用卡」\n4. 掃描卡片條碼\n5. 完成設定\n\n步驟 4：設定密碼\n- 電話密碼：電話交易使用（6碼數字）\n- 網路密碼：網路交易使用（8-12碼英數）\n- ATM密碼：預借現金使用（6碼數字）\n\n密碼安全建議：\n- 勿使用生日、電話等\n- 定期更換密碼\n- 不同服務使用不同密碼\n- 妥善保管密碼\n\n========================================\n第二章：紅利點數累積與兌換\n========================================'), -0.013565114666354239), (Document(metadata={'source': '健保就醫指南.txt'}, page_content='9.1 醫療爭議處理\n醫療爭議處理管道:\n1. 與醫療院所溝通協調\n2. 向醫院客訴單位申訴\n3. 向衛生局申訴\n4. 申請調解\n5. 司法途徑\n\n9.2 健保業務申訴\n申訴管道:\n- 健保署服務專線: 0800-030-598\n- 各地健保署分區業務組\n- 健保署網站線上申辦\n- 書面申訴\n\n常見申訴案件:\n- 醫療院所收費爭議\n- 健保卡使用問題\n- 給付認定爭議\n- 就醫權益受損\n\n9.3 保費欠費處理\n欠費影響:\n- 3個月內: 暫停保險給付\n- 可自費就醫,補繳後核退\n- 累計欠費: 列管催繳\n\n補繳方式:\n- 便利商店繳費\n- 金融機構繳費\n- 健保署臨櫃繳費\n- ATM轉帳\n- 信用卡繳費\n\n分期繳納:\n- 欠費達一定金額可申請分期\n- 最長24期\n\n第十章: 常見問題\n\nQ1: 健保卡忘記帶怎麼辦?\nA: 可先自費就醫,於就醫日起6個月內,持健保卡、收據、診斷證明至健保署申請核退。\n\nQ2: 可以同時看多家醫院嗎?\nA: 可以,但同一疾病建議固定一家醫院就診較佳。\n\nQ3: 慢性病處方箋可以提前領藥嗎?\nA: 不可以,需等到上次領藥日期加上藥量天數才能再次領藥。\n\nQ4: 住院可以選擇醫生嗎?\nA: 可以,但指定醫師費需自付。\n\nQ5: 就醫後對診斷有疑慮怎麼辦?\nA: 可尋求第二醫療意見(second opinion),至其他醫院就診。\n\nQ6: 健保卡內的就醫紀錄可以刪除嗎?\nA: 不可以,就醫紀錄為醫療參考依據。\n\nQ7: 看診時醫師說這是自費項目,合理嗎?\nA: 健保有給付範圍限制,特殊檢查或材料可能需自費,可詢問是否有健保給付替代方案。\n\nQ8: 急診等很久,可以抱怨嗎?\nA: 急診依檢傷分級處理,若無急迫性需等候,建議改掛門診。\n\n重要電話\n健保署服務專線: 0800-030-598\n健保卡掛失專線: 0800-030-598\n健保快易通APP: 可查詢就醫紀錄、繳費記錄\n\n健保署網站: www.nhi.gov.tw\n各地健保署分區業務組: 請上健保署網站查詢\n\n注意: 本指南為簡化版,詳細規定請以健保署公告為準。健保相關規定可能隨時更新,請定期至健保署網站查詢最新資訊。'), -0.014281358209948358)]
#   self.vectorstore.similarity_search_with_relevance_scores(
# No relevant docs were retrieved using the relevance score threshold 0.1
# --- 相關文件 ---
#
# --- 只從《路由器設定手冊》檢索 ---
# 文件 1:
# 2.3 使用手機 App設定
# ----------------------------------------
# 步驟 1：下載 App
# - iOS：至 App Store搜尋「TR Router」
# - Android：至 Play商店搜尋「TR Router」
# - 或掃描說明書上的 QR Code
#
# 步驟 2：連接路由器 WiFi
# - 開啟手機 WiFi設定
# - 連接預設 WiFi：TR-5000_XXXX
# - 輸入預設密碼（路由器底部標籤）
#
# 步驟 3：開啟 App設定
# 1. 啟動 TR Router App
# 2. App會自動偵測路由器
# 3. 點選「開始設定」
# 4. 依畫面指示完成設定
#
# 步驟 4：設定內容
# 與電腦版相同：
# - 建立管理員密碼
# - 設定網際網路連線
# - 完成後可立即使用
#
# 優點：
# - 操作介面更友善
# - 支援遠端管理
# - 即時通知功能
# - 輕鬆管理連線裝置
#
# ========================================
# 第三章：WiFi 無線網路設定
# ========================================
#
# 3.1 WiFi 基本設定
# ----------------------------------------
# 進入 WiFi設定：
# 1. 登入管理介面（192.168.1.1）
# 2. 點選「無線網路」→「基本設定」
#
# 2.4GHz 頻段設定：
# 網路名稱（SSID）：
# - 建議使用易記且安全的名稱
# - 避免使用個人資訊（如地址、電話）
# - 支援中文但部分裝置可能無法顯示
# - 範例：Home_2.4G、MyHome_24
#
# 安全性設定：
# - 加密方式：選擇「WPA3-Personal」（最安全）
# - 若有舊裝置不支援，選「WPA2/WPA3 混合模式」
# - 密碼長度：8-63字元
# - 建議密碼格式：英文大小寫+數字+符號
#
# 頻道設定：
# - 建議選擇「自動」
# - 手動選擇：1、6、11（較少干擾）
# - 頻道寬度：20/40MHz 自動
#
# 5GHz 頻段設定：
# 網路名稱（SSID）：
# - 建議與 2.4G區分（如加上_5G）
# - 範例：Home_5G、MyHome_5G
#
# 頻道設定：
# - 建議選擇「自動」
# - 手動選擇：36、40、44、48（DFS頻段需注意）
# - 頻道寬度：20/40/80MHz 自動
#
# 來源: 路由器設定手冊.txt
#
# 文件 2:
# 用戶端連線：
# 手機：
# - 下載「OpenVPN Connect」App
# - 匯入 .ovpn設定檔
# - 輸入帳號密碼連線
#
# 電腦：
# - 下載 OpenVPN GUI軟體
# - 匯入設定檔
# - 點選連線
#
# 7.5 系統日誌與診斷
# ----------------------------------------
# 系統日誌：
# 1. 「系統設定」→「系統日誌」
# 2. 可查看：
#    - 連線紀錄
#    - 系統錯誤
#    - 安全事件
#    - DHCP分配紀錄
#
# 日誌等級：
# - 資訊：一般事件
# - 警告：需注意事項
# - 錯誤：系統錯誤
#
# 診斷工具：
# Ping測試：
# - 測試與特定主機連線
# - 檢查網路連通性
#
# Traceroute：
# - 追蹤封包路徑
# - 找出連線瓶頸
#
# 速度測試：
# - 內建測速功能
# - 快速檢測網速
#
# ========================================
# 附錄：常見問題 FAQ
# ========================================
#
# Q1：忘記管理員密碼怎麼辦？
# A1：只能重置路由器恢復原廠設定，所有設定將清除。
#
# Q2：WiFi訊號要怎麼加強？
# A2：(1)調整路由器位置 (2)更換頻道 (3)加裝延伸器 (4)升級天線
#
# Q3：2.4G和 5G有什麼差別？
# A3：
# - 2.4G：範圍較廣、穿牆較好、速度較慢、干擾較多
# - 5G：範圍較小、穿牆較差、速度較快、干擾較少
#
# Q4：要選擇哪個 WiFi頻段？
# A4：
# - 距離遠、隔牆多 → 2.4G
# - 同一房間、需要高速 → 5G
# - 建議啟用雙頻合一，自動選擇
#
# Q5：路由器需要關機嗎？
# A5：不需要，但建議每月重新啟動一次，清除暫存記憶體。
#
# Q6：幾年需要更換路由器？
# A6：一般 3-5年，或當：
# - 韌體不再更新
# - 速度無法滿足需求
# - 經常當機
# - 不支援新技術（如 WiFi 6）
#
# ========================================
# 技術支援資訊
# ========================================
#
# 客服專線：0800-567-890
# 服務時間：每日 09:00-21:00
#
# 來源: 路由器設定手冊.txt
#
# 文件 3:
# 路由器設定手冊
# ========================================
#
# 產品型號：TR-5000 雙頻無線路由器
# 製造商：台灣網通科技股份有限公司
# 技術支援：0800-567-890
# 官方網站：www.taiwanrouter.com.tw
#
# ========================================
# 第一章：硬體規格與特色
# ========================================
#
# 1.1 產品規格
# ----------------------------------------
# 型號：TR-5000
# 無線標準：IEEE 802.11ax (WiFi 6)
# 傳輸速率：
# - 2.4GHz：最高 574 Mbps
# - 5GHz：最高 2402 Mbps
# - 總和速率：2976 Mbps (AX3000)
#
# 處理器：1.5GHz 四核心處理器
# 記憶體：512MB RAM / 256MB Flash
# 天線：外接式 4根（支援波束成型）
# 網路介面：
# - 1個 WAN埠（10/100/1000 Mbps）
# - 4個 LAN埠（10/100/1000 Mbps）
# - 1個 USB 3.0埠
#
# 支援裝置數：最多 128個裝置同時連線
# 訊號範圍：約 150坪（開放空間）
# 電源規格：DC 12V / 2A
# 尺寸：260mm × 160mm × 45mm
# 重量：450公克
#
# 1.2 主要功能特色
# ----------------------------------------
# WiFi 6 技術：
# - OFDMA技術（提升多裝置效率）
# - MU-MIMO（多用戶同時傳輸）
# - BSS Coloring（降低干擾）
# - Target Wake Time（省電功能）
#
# 安全防護：
# - WPA3加密（最新安全標準）
# - 防火牆保護
# - DoS攻擊防禦
# - 家長控制功能
# - VPN伺服器支援
#
# 智慧管理：
# - 手機 App遠端管理
# - 自動韌體更新
# - QoS頻寬管理
# - 訪客網路獨立
# - 網路診斷工具
#
# 來源: 路由器設定手冊.txt

# %%
# 第3個儲存格：整合 Chain - 多來源文件的智慧問答鏈

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_ollama import ChatOllama

# 定義使用者的問題
question = "如何保養洗衣機和路由器？"

print(f"❓ 使用者問題: {question}\n")

# 步驟 1: 從多個來源檢索相關文件
print("=" * 70)
print("步驟 1: 從多個來源檢索相關文件")
print("=" * 70)

retriever = db.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}  # 取4個相關文件（可能來自不同手冊）
)

retrieved_docs = retriever.invoke(question)

print(f"✅ 找到 {len(retrieved_docs)} 個相關文件\n")
for i, doc in enumerate(retrieved_docs, 1):
    source = doc.metadata.get('source', 'Unknown')
    print(f"📄 文件 {i} - 來源: {source}")
    print(f"   內容: {doc.page_content[:80]}...\n")

# 步驟 2: 建立帶有來源標註的 RAG Chain
print("=" * 70)
print("步驟 2: 建立多來源 RAG Chain")
print("=" * 70)

# 定義提示模板（強調來源資訊）
template = """你是一個專業的產品客服助手。請根據以下多個產品手冊的參考資料回答使用者的問題。

參考資料：
{context}

使用者問題：{question}

回答要求：
1. 針對不同產品分別說明（如果問題涉及多個產品）
2. 在回答中標註資訊來源（例如：「根據洗衣機使用說明...」）
3. 只根據參考資料回答，不要編造內容
4. 如果某個產品的資訊不足，請說明
5. 用條列式整理，讓使用者容易閱讀

回答："""

prompt = ChatPromptTemplate.from_template(template)

# 建立 LLM
llm = ChatOllama(model="gpt-oss:20b", temperature=0)

# 定義文件格式化函數（包含來源資訊）
def format_docs_with_source(docs):
    formatted = []
    for i, doc in enumerate(docs, 1):
        source = doc.metadata.get('source', 'Unknown')
        formatted.append(f"【來源 {i}: {source}】\n{doc.page_content}")
    return "\n\n---\n\n".join(formatted)

# 建立完整的 RAG Chain（整合 3_chains 的技巧）
rag_chain = (
    {
        "context": retriever | format_docs_with_source, 
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

print("✅ 多來源 RAG Chain 建立完成\n")

# 步驟 3: 執行 Chain 並取得整合答案
print("=" * 70)
print("步驟 3: 執行 Chain 取得整合答案")
print("=" * 70)

answer = rag_chain.invoke(question)

print(f"\n🤖 【AI 整合回答】\n")
print(answer)
print()

# 步驟 4: 示範使用元數據過濾的 Chain
print("=" * 70)
print("步驟 4: 只查詢特定來源的 Chain")
print("=" * 70)

specific_question = "路由器如何設定？"
print(f"❓ 問題: {specific_question}\n")

# 創建只查詢路由器手冊的檢索器
def retrieve_from_router_manual(query):
    docs = db.similarity_search(
        query,
        k=3,
        filter={"source": "路由器設定手冊.txt"}
    )
    return docs

# 建立特定來源的 Chain
specific_chain = (
    {
        "context": RunnablePassthrough() | retrieve_from_router_manual | format_docs_with_source,
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | StrOutputParser()
)

specific_answer = specific_chain.invoke(specific_question)
print(f"🤖 【只查路由器手冊的回答】\n")
print(specific_answer)
print()

print("=" * 70)
print("📚 多來源 RAG Chain 的優勢")
print("=" * 70)
print("✅ 可以同時查詢多個產品手冊")
print("✅ 自動標註資訊來源，方便追蹤")
print("✅ 可以用 metadata 過濾特定來源")
print("✅ 整合多個文件的資訊給出完整答案")
print("\n💡 這展示了 Chain 3 中學到的組合技巧在 RAG 中的應用！")
# Out:
# ❓ 使用者問題: 如何保養洗衣機和路由器？
#
# ======================================================================
# 步驟 1: 從多個來源檢索相關文件
# ======================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      15 print("步驟 1: 從多個來源檢索相關文件")
#      16 print("=" * 70)
# ---> 18 retriever = db.as_retriever(
#      19     search_type="similarity",
#      20     search_kwargs={"k": 4}  # 取4個相關文件（可能來自不同手冊）
#      21 )
#      23 retrieved_docs = retriever.invoke(question)
#      25 print(f"✅ 找到 {len(retrieved_docs)} 個相關文件\n")
#
# NameError: name 'db' is not defined
